# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_classification

X, y = make_classification(n_samples=1000, n_classes=3, n_features=10, n_informative=3)

# %%
X
# Out:
# array([[ 0.71816751,  0.34239136, -1.35840044, ..., -0.91534912,
#          0.10954084,  1.55214377],
#        [ 0.14396798, -0.21585806,  0.68876826, ..., -0.73889865,
#         -1.23061543, -0.30794553],
#        [ 1.38124344,  1.73606908, -0.82464871, ...,  0.79265739,
#          0.50749216,  0.19532665],
#        ...,
#        [-0.04896804, -0.62512346, -0.17999862, ..., -0.33486618,
#         -0.46997625,  0.90961985],
#        [ 0.36051523, -1.88671838,  0.27121365, ...,  1.70620421,
#          1.51800357,  1.32652439],
#        [-0.16871872,  0.93523589,  0.79033277, ...,  1.18329252,
#          1.14931141, -1.55521169]], shape=(100000, 10))

# %%
y
# Out:
# array([0, 2, 1, ..., 2, 1, 2], shape=(100000,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30)

# %%
from sklearn.linear_model import LogisticRegression

logistic = LogisticRegression(multi_class='ovr')
